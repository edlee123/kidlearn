# %% [markdown]
# Bonjourno serniorita

# %%
import sys
import os
sys.path.append("..")
sys.path.append("../kidlearn_lib/")

# %%
import kidlearn_lib as k_lib
reload(k_lib)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-7b3c188f7af1> in <module>()
# ----> 1 import kidlearn_lib.functions as k_lib
#       2 reload(k_lib)
#
# /home/bclement/Dropbox/INRIA/kidlearn4.0/kidlearn/kidlearn_lib/__init__.py in <module>()
#       1 import functions
# ----> 2 import knowledge
#       3 import student
#       4 import seq_manager
#       5 import exercise
#
# /home/bclement/Dropbox/INRIA/kidlearn4.0/kidlearn/kidlearn_lib/knowledge/__init__.py in <module>()
# ----> 1 from .knowledge import Knowledge
#       2 from .kt_knowledge import KT_knowledge
#       3 from .kt_features import KT_features
#
# /home/bclement/Dropbox/INRIA/kidlearn4.0/kidlearn/kidlearn_lib/knowledge/knowledge.py in <module>()
#      17 import pickle
#      18 import json
# ---> 19 from functions import *
#      20
#      21 class Knowledge(object):
#
# ...

# %%
k_lib.simulation.Simulation()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-f4b227621999> in <module>()
# ----> 1 k_lib.simulation.Simulation()
#
# /home/bclement/Dropbox/INRIA/kidlearn4.0/kidlearn/kidlearn_lib/simulation.pyc in __init__(self, seq_manager_list_name, nb_students, nb_ex, model_student, ref, *args, **kwargs)
#     243         self._population = self.define_population()
#     244         for seq_manager_name in self._seq_manager_list_name:
# --> 245             self.add_working_group(copy.deepcopy(self._population),seq_manager_name)
#     246
#     247         #self.population_simulation()
#
# /home/bclement/Dropbox/INRIA/kidlearn4.0/kidlearn/kidlearn_lib/simulation.pyc in add_working_group(self, population, seq_manager_name)
#     258
#     259     def add_working_group(self,population,seq_manager_name):
# ...
